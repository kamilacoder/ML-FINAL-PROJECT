# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# <center><align centre><h1 style="color: blue;">The World is surrounded by Social Media</h1></center>

# %% [markdown]
# <h1 style="color: blue;"><u>Domain</u></h1>
#
# <h2 style="color: violet;">Social Media Analysis the fastest-growing communication medium</h2>

# %% [markdown]
# <h1 style="color: blue;"><u>Problem Statement</u></h1>
#
# <h2 style="color: violet;">Social Media has become a popular place for people to express their opinion about
# a brand, talk about it, and give feedback. It’s helps in understanding people's
# sentiment over any topic and incident. Analyzing sentiments help in understanding
# how people are thinking emotionally and classifying it as negative, positive or
# neutral</h2>

# %% [markdown]
# <h2 style="color: Green;"><u><i>Dataset</u></i></h2>

# %%
df = pd.read_csv('https://raw.githubusercontent.com/kamilacoder/sentimentdataset1/refs/heads/main/sentimentdataset1.csv')

# %%
df.head(10)
# Out:
#    Unnamed: 0.1  Unnamed: 0  \
# 0             0           0
# 1             1           1
# 2             2           2
# 3             3           3
# 4             4           4
# 5             5           5
# 6             6           6
# 7             7           7
# 8             8           8
# 9             9           9
#
#                                                 Text    Sentiment  \
# 0   Enjoying a beautiful day at the park!        ...   Positive
# 1   Traffic was terrible this morning.           ...   Negative
# 2   Just finished an amazing workout! 💪          ...   Positive
# 3   Excited about the upcoming weekend getaway!  ...   Positive
# 4   Trying out a new recipe for dinner tonight.  ...   Neutral
# 5   Feeling grateful for the little things in lif...   Positive
# 6   Rainy days call for cozy blankets and hot coc...   Positive
# 7   The new movie release is a must-watch!       ...   Positive
# 8   Political discussions heating up on the timel...   Negative
# ...

# %% [markdown]
# <h2 style="color: Green;"><u><i>Data Description</u></i></h2>
#
# <h2 style="color: violet;">A data description provides information about a datase</h2>

# %%
df.describe()
# Out:
#        Unnamed: 0.1  Unnamed: 0    Retweets       Likes         Year  \
# count    732.000000  732.000000  732.000000  732.000000   732.000000
# mean     366.464481  369.740437   21.508197   42.901639  2020.471311
# std      211.513936  212.428936    7.061286   14.089848     2.802285
# min        0.000000    0.000000    5.000000   10.000000  2010.000000
# 25%      183.750000  185.750000   17.750000   34.750000  2019.000000
# 50%      366.500000  370.500000   22.000000   43.000000  2021.000000
# 75%      549.250000  553.250000   25.000000   50.000000  2023.000000
# max      732.000000  736.000000   40.000000   80.000000  2023.000000
#
#             Month         Day        Hour
# count  732.000000  732.000000  732.000000
# mean     6.122951   15.497268   15.521858
# std      3.411763    8.474553    4.113414
# min      1.000000    1.000000    0.000000
# 25%      3.000000    9.000000   13.000000
# 50%      6.000000   15.000000   16.000000
# 75%      9.000000   22.000000   19.000000
# ...

# %% [markdown]
# <h2 style="color: green;"><u><i>Target</u></i></h2>
#
# <h3><b><u>Likes_stats:</u></b></h3> <h4>Displays summary stats for the number of likes on posts.<h4>
# <h3><b><u>Platform_stats:</u></b></h3> <h4> Shows stats for the platform distribution (if categorical, it might give counts).</h4>
# <h3><b><u>Retweets_stats:</u></b></h3> <h4> Provides insights into retweet behavior.</h4>

# %%
import pandas as pd

# Sample DataFrame
data = {'Likes': [120, 450, 230, 580, 310],
        'Retweets': [30, 120, 85, 190, 75],
        'Platform': ['Twitter', 'Instagram', 'Twitter', 'Facebook', 'Instagram']}

df = pd.DataFrame(data)

# Compute statistics
Likes_stats = df['Likes'].describe()
Platform_stats = df['Platform'].describe()
Retweets_stats = df['Retweets'].describe()

print(Likes_stats)
print(Platform_stats)
print(Retweets_stats)
# Out:
# count      5.00000
# mean     338.00000
# std      181.02486
# min      120.00000
# 25%      230.00000
# 50%      310.00000
# 75%      450.00000
# max      580.00000
# Name: Likes, dtype: float64
# count           5
# unique          3
# top       Twitter
# freq            2
# Name: Platform, dtype: object
# count      5.000000
# mean     100.000000
# std       59.686682
# min       30.000000
# 25%       75.000000
# 50%       85.000000
# 75%      120.000000
# max      190.000000
# Name: Retweets, dtype: float64

# %% [markdown]
# <h2 style="color: violet;">Identify and Handle Outliers:</h2>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12,6))
sns.boxplot(data=df[['Likes', 'Platform', 'Hour', 'Retweets']])
plt.title("Boxplots for Score Distribution")
plt.show()

# %% [markdown]
# <h2 style="color: violet;">Calculate the Interquartile Range(IQR)  &  Determine the lower and upper bounds for IQR</h2>

# %%
# Compute Q1 (25th percentile) and Q3 (75th percentile)
Q1 = df[['Likes', 'Hour', 'Retweets']].quantile(0.25)
Q3 = df[['Likes', 'Hour', 'Retweets']].quantile(0.75)

# Compute IQR'Likes', 'Hour', 'Retweets'
IQR = Q3 - Q1
print("Interquartile Range (IQR):\n", IQR)
# Out:
# Interquartile Range (IQR):
#  Likes       15.25
# Hour         6.00
# Retweets     7.25
# dtype: float64

# %%
# Define lower and upper bounds
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

print("Lower Bound:\n", lower_bound)
print("Upper Bound:\n", upper_bound)
# Out:
# Lower Bound:
#  Likes       11.875
# Hour         4.000
# Retweets     6.875
# dtype: float64
# Upper Bound:
#  Likes       72.875
# Hour        28.000
# Retweets    35.875
# dtype: float64

# %%
filtered_df = df[~((df[['Likes', 'Hour', 'Retweets']] < lower_bound) | 
                   (df[['Likes', 'Hour', 'Retweets']] > upper_bound)).any(axis=1)]

print("Original Dataset Size:", df.shape)
print("Filtered Dataset Size (after outlier removal):", filtered_df.shape)
# Out:
# Original Dataset Size: (732, 15)
# Filtered Dataset Size (after outlier removal): (709, 15)

# %% [markdown]
# <h2 style="color: violet;">Handle the outliers by removing them from the dataset.</h2>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# Assume df is your DataFrame containing the score columns
score_columns = ['Likes', 'Hour', 'Retweets', 'Platform']

for col in score_columns:
    plt.figure(figsize=(6, 4))
    sns.histplot(df[col], kde=True, bins=30)
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 6))

# Math score histogram
sns.histplot(df["Likes"], kde=True, bins=20, edgecolor='black', color="teal", ax=axes[0])
axes[0].set_title('Removing outliers for Likes', fontsize=16, fontweight="bold")

# Math score histogram
sns.histplot(df["Platform"], kde=True, bins=20, edgecolor='black', color="teal", ax=axes[1])
axes[1].set_title('Removing outliers for Platform', fontsize=16, fontweight="bold")

plt.tight_layout()
plt.show()

# %% [markdown]
# <h2 style="color: violet;">Calculate and interpret the skewness for each of these score columns</h2>

# %%
print(df['Likes'].skew())

print(df['Year'].skew())
# Out:
# 0.37813850875791316
# -1.0292915904683033

# %% [markdown]
# <h2 style="color: violet;">Discuss whether the distributions are skewed to the left or right and suggest any appropriate transformations if needed to address skewness</h2>

# %%
def anlys_skewness(data):
    skewness = data.skew()
    print("\n")
    if skewness > 0:
        print("Positively skewed (right skewed).")
        print("Apply a log or square root .")
    elif skewness < 0:
        print("Negatively skewed (left skewed).")
        print("Apply a reflection and then log or square root.")
    else:
        print("This is approximately symmetrical.")
        print("No transformation needed.")


anlys_skewness(df['Likes'])
anlys_skewness(df['Retweets'])
anlys_skewness(df['Hour'])
# Out:
# Positively skewed (right skewed).
# Apply a log or square root .
#
#
# Positively skewed (right skewed).
# Apply a log or square root .
#
#
# Negatively skewed (left skewed).
# Apply a reflection and then log or square root.

# %%
m_log =df.copy()
m_log["LogM_alt"] = np.log1p(m_log["Likes"])
r_log =df.copy()
r_log["LogR_alt"] = np.log1p(r_log["Retweets"])
w_log =df.copy()
w_log["LogW_alt"] = np.log1p(w_log["Year"])

# %%
fig, axes = plt.subplots(1, 3, figsize=(18, 6))
sns.histplot(m_log["LogM_alt"], ax=axes[0], kde=True, fill=True)
sns.histplot(r_log["LogR_alt"], ax=axes[1], kde=True, fill=True)
sns.histplot(w_log["LogW_alt"], ax=axes[2], kde=True, fill=True)
plt.tight_layout()
plt.show()

# %%
print(dataset.columns)
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'Text', 'Sentiment', 'Timestamp', 'User',
#        'Platform', 'Hashtags', 'Retweets', 'Likes', 'Country', 'Year', 'Month',
#        'Day', 'Hour'],
#       dtype='object')
